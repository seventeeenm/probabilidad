# %% [markdown]
# <a href="https://colab.research.google.com/github/seventeeenm/probabilidad/blob/main/Unidad1/Practica_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y Estadística**<hr>
# ##**Unidad 1**
# #**Practica 4: Diagrama de cajas y bigotes**
# Profesor: Dr. Jose Gabriel Rodríguez Rivas<br>
# Alumno: Dilan Yahir Escareño Duran

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
      numero_aleatorio=round(random.uniform(50, 100), 2)
      fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [85.36, 50.7, 55.95, 87.11, 75.13, 56.74, 76.0, 83.82, 51.83, 95.18, 70.62, 76.81, 87.53, 92.28, 53.93, 93.48, 82.1, 64.51, 92.81, 54.12, 97.96, 65.34, 70.76, 76.69, 67.24, 61.53, 73.71, 79.29, 99.89, 85.96, 92.57, 95.12, 92.2, 86.08, 93.97, 96.94, 64.63, 64.69, 78.64, 74.3, 75.99, 59.44, 67.59, 85.23, 66.13, 97.95, 59.78, 81.97, 65.59, 69.22, 56.87, 70.65, 64.64, 56.21, 59.8, 90.7, 78.25, 57.07, 64.04, 95.04, 67.79, 67.87, 82.46, 51.89, 95.71, 86.89, 50.51, 53.43, 65.08, 99.07, 61.0, 69.69, 60.24, 87.33, 53.48, 97.47, 69.69, 66.22, 91.7, 98.68, 75.49, 98.31, 61.03, 59.13, 83.49, 61.16, 88.51, 76.69, 67.13, 50.64, 55.78, 80.59, 74.9, 50.35, 51.26, 72.66, 78.37, 94.58, 96.37, 95.67]

# %%
fabrica2 = []
for i in range(100):
      numero_aleatorio=round(random.uniform(50, 100), 2)
      fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [68.02, 82.81, 96.25, 51.47, 95.45, 62.51, 50.89, 58.5, 93.55, 75.75, 99.18, 67.66, 72.04, 55.86, 57.63, 51.14, 92.78, 75.63, 72.63, 86.28, 85.85, 55.48, 67.23, 91.96, 56.43, 83.36, 97.86, 91.43, 71.33, 83.42, 97.04, 91.78, 74.81, 56.48, 82.5, 68.19, 64.51, 80.85, 96.66, 71.85, 55.46, 71.81, 66.46, 65.9, 78.58, 62.53, 90.55, 72.22, 59.45, 84.16, 52.13, 56.09, 66.33, 56.1, 84.37, 52.74, 50.44, 62.29, 55.99, 75.03, 71.68, 58.0, 73.21, 79.12, 83.48, 52.4, 92.29, 86.97, 73.62, 50.92, 92.3, 51.6, 60.8, 79.48, 57.12, 83.9, 84.0, 59.14, 62.64, 54.66, 85.32, 56.25, 55.72, 61.46, 77.28, 56.6, 94.66, 78.69, 83.9, 63.9, 93.04, 56.5, 94.32, 74.06, 56.43, 59.73, 86.33, 71.23, 69.84, 66.52]

# %% [markdown]
# **Diagrama de cajas y bigotes**
#
#
# 1.   Las lineas se usan para indicar la variabilidad fuera de los cuartiles superior e inferior.
# 2.   Los valores atípicos se representan a veces como puntos individuales que estan en linea con los bigotes.
# 3. **Si los datos son simetricos, la mediana estara en el centro de la caja.**
# 4. Si los datos estan **sesgados**, la mediana estara mas cerca de la parte superior o inferior de la caja.

# %%
plt.figure(figsize=(5, 4))
plt.boxplot(fabrica1, patch_artist=True, boxprops=dict(facecolor='salmon'))
plt.ylabel('Edades')
plt.title('Produccion Fabrica 1')
plt.grid(True)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows =1, ncols =2, figsize=(9, 4))
bplot = ax1.boxplot(fabrica1,
                    vert = True,
                    patch_artist=True,
                    boxprops=dict(facecolor='salmon'))
ax1.set_title('Produccion Fabrica 1')
bplot = ax2.boxplot(fabrica2,
                    vert = True,
                    patch_artist=True, #yadira te amo
                    boxprops=dict(facecolor='salmon'))
ax2.set_title('Produccion Fabrica 2')
plt.show()

# %%
#Insertamos un valor de 150 a la fabrica 1
#Seria un valor atipico
fabrica1.append(150)
print(fabrica1)
# Out:
# [85.36, 50.7, 55.95, 87.11, 75.13, 56.74, 76.0, 83.82, 51.83, 95.18, 70.62, 76.81, 87.53, 92.28, 53.93, 93.48, 82.1, 64.51, 92.81, 54.12, 97.96, 65.34, 70.76, 76.69, 67.24, 61.53, 73.71, 79.29, 99.89, 85.96, 92.57, 95.12, 92.2, 86.08, 93.97, 96.94, 64.63, 64.69, 78.64, 74.3, 75.99, 59.44, 67.59, 85.23, 66.13, 97.95, 59.78, 81.97, 65.59, 69.22, 56.87, 70.65, 64.64, 56.21, 59.8, 90.7, 78.25, 57.07, 64.04, 95.04, 67.79, 67.87, 82.46, 51.89, 95.71, 86.89, 50.51, 53.43, 65.08, 99.07, 61.0, 69.69, 60.24, 87.33, 53.48, 97.47, 69.69, 66.22, 91.7, 98.68, 75.49, 98.31, 61.03, 59.13, 83.49, 61.16, 88.51, 76.69, 67.13, 50.64, 55.78, 80.59, 74.9, 50.35, 51.26, 72.66, 78.37, 94.58, 96.37, 95.67, 150]

# %%
fig, (ax1, ax2) = plt.subplots(nrows =1, ncols =2, figsize=(9, 4))
bplot = ax1.boxplot(fabrica1,
                    vert = True,
                    patch_artist=True,
                    boxprops=dict(facecolor='salmon'))
ax1.set_title('Produccion Fabrica 1')
bplot = ax2.boxplot(fabrica2,
                    vert = True,
                    patch_artist=True,
                    boxprops=dict(facecolor='salmon'))
ax2.set_title('Produccion Fabrica 2')
plt.show()
